# %% [markdown]
# # This file will focus more on the merging of the csv

# %%
#Note that the csv generation file needs to be run first for this to work (assuming only user access is to the excel files)

#python 3.11.9

import os
import pandas as pd
from datetime import datetime

def add_publication_date(input_folder, output_folder):
    # Create the output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)

    for filename in os.listdir(input_folder):
        if filename.endswith('.csv'):
            input_path = os.path.join(input_folder, filename)
            output_path = os.path.join(output_folder, filename)

            # Extract date from filename
            date_str = filename[-10:-4]  # Extract YYYYMM
            date = datetime.strptime(date_str, '%Y%m')
            formatted_date = date.strftime('%m/%Y')

            # Read CSV
            df = pd.read_csv(input_path)

            # Add Publication Date column
            df['Publication Date'] = formatted_date

            # Save updated CSV
            df.to_csv(output_path, index=False)
            print(f"Added Publication Date to {filename}")

# Set up input and output folders
current_dir = os.getcwd()
input_folder = os.path.join(current_dir, 'csv_files')
output_folder = os.path.join(current_dir, 'updated_csv_files')

# Process CSV files
add_publication_date(input_folder, output_folder)
# Out:
# Added Publication Date to TOP500_199306.csv
# Added Publication Date to TOP500_199311.csv
# Added Publication Date to TOP500_199406.csv
# Added Publication Date to TOP500_199411.csv
# Added Publication Date to TOP500_199506.csv
# Added Publication Date to TOP500_199511.csv
# Added Publication Date to TOP500_199606.csv
# Added Publication Date to TOP500_199611.csv
# Added Publication Date to TOP500_199706.csv
# Added Publication Date to TOP500_199711.csv
# Added Publication Date to TOP500_199806.csv
# Added Publication Date to TOP500_199811.csv
# Added Publication Date to TOP500_199906.csv
# Added Publication Date to TOP500_199911.csv
# Added Publication Date to TOP500_200006.csv
# Added Publication Date to TOP500_200011.csv
# Added Publication Date to TOP500_200106.csv
# Added Publication Date to TOP500_200111.csv
# Added Publication Date to TOP500_200206.csv
# Added Publication Date to TOP500_200211.csv
# Added Publication Date to TOP500_200306.csv
# ...

# %%
import pandas as pd
import os

#Note that over the years, new data was tested and analyzed, so things like power may not have always been covered. In this merge, those columns are left blank (Nan) when applicable

def merge_csv_files(input_folder, output_file):
    # Get a list of all CSV files in the input folder
    csv_files = [f for f in os.listdir(input_folder) if f.endswith('.csv')]
    
    # Read and store all DataFrames in a list
    dfs = []
    for file in csv_files:
        file_path = os.path.join(input_folder, file)
        df = pd.read_csv(file_path)
        dfs.append(df)
    
    # Concatenate all DataFrames
    merged_df = pd.concat(dfs, ignore_index=True, sort=False)
    
    # Save the merged DataFrame to a new CSV file
    merged_df.to_csv(output_file, index=False)
    print(f"Merged CSV saved to {output_file}")

# Set up input and output paths
current_dir = os.getcwd()
input_folder = os.path.join(current_dir, 'updated_csv_files')
output_file = os.path.join(current_dir, 'merged_top500_nans.csv')

# Merge CSV files
merge_csv_files(input_folder, output_file)
# Out:
# Merged CSV saved to c:\VSCode\top500_data\merged_top500_nans.csv
